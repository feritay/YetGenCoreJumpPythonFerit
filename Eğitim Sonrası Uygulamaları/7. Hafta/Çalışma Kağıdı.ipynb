# %% [markdown]
# # Problem 1 Aradaki Tam Sayılar
#
# Kullanıcıdan iki adet sayı alınız, bu sayılar arasındaki tam sayıları ekrana yazdıran bir program yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

birinciSayi = int(input("Birinci sayiyi girin:"))
ikinciSayi = int(input("İkinci sayiyi girin:"))

if birinciSayi>ikinciSayi:
    birinciSayi, ikinciSayi = ikinciSayi, birinciSayi

for x in range(birinciSayi+1,ikinciSayi):
    print(x)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %% [markdown]
# # Problem 2 Faktöriyel
#
# Kullanıcıdan bir sayı alınız ve alınan sayının faktöriyelini hesaplayan bir program yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

sayi = int(input("Sayi girin:"))

faktoriyel = 1
for i in range(1, sayi + 1):
    faktoriyel *= i

print(f"{sayi}! = {faktoriyel}")
# Out:
# 5! = 120

# %% [markdown]
# # Problem 3 Virgül ile Ayırma
#
# Kullanıcıdan bir metin halinde virgül ile ayrılmış sayılar alınız ve aldığınız her bir sayıyı listeye atayınız, daha sonra listedeki her elemanı toplayıp ekrana bastıran bir program yazınız.
#
# <h4>Sample Input</h4>
# <p>
# Lutfen sayilari virgul ile ayrirarak giriniz: 5,14,7,2,1
# </p>
# <h4>Output</h4>
#
# Toplam: 29

# %%
# 3.Problemin Çözümünü Buraya Yazınız

sayilar = input("Virgülle ayrilmiş sayilari girin: ")
sayiListesi = sayilar.split(",")

sayiListesi = [int(x) for x in sayiListesi]
toplam = sum(sayiListesi)

print(f"Girilen sayilarin toplami:{toplam}")
# Out:
# Girilen sayilarin toplami:29

# %% [markdown]
# # Problem 4 Büyük Sayı
#
# Kullanıcıdan alınan iki sayıdan büyük olanı bulup, ekrana yazdıran bir fonksiyon yazınız.

# %%
# 4.Problemin Çözümünü Buraya Yazınız

ilkSayi = int(input("Bir sayi girin:"))
sonSayi = int(input("Bir sayi daha girin:"))

if ilkSayi>sonSayi == True:
    print(f"Büyük olan sayi:{ilkSayi}")
else:
     print(f"Büyük olan sayi:{sonSayi}")
# Out:
# Büyük olan sayi:225

# %% [markdown]
# # Problem 5 Ürün Kayıt Uygulaması
# Programımız ilk olarak kullanıcıdan, kaydı yapılacak ürünlerin sayısını isteyecek. Ardından yazılmış olan ürün sayısı kadar ürün ismi ve ürün fiyatı bilgisini kullanıcıdan alacak. Son olarak ise ürünleri ekrana yazdıracağız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen kac adet urun gireceginizi yaziniz: 3
# <br/>
# 1. Urununuzun ismini giriniz: Mentos
# <br/>
# 1. Urununuzun fiyatini giriniz: 1
# <br/>
# 2. Urununuzun ismini giriniz: Meybuz
# <br/>
# 2. Urununuzun fiyatini giriniz: 0.25
# <br/>
# 3. Urununuzun ismini giriniz: Uzun Şeker
# <br/>
# 3. Urununuzun fiyatini giriniz: 0.75
# <br/>
# <h4>Output:</h4>
# 1. Urun: Mentos - 1 TL
# <br/>
# 2. Urun: Meybuz - 0.25 TL
# <br/>
# 3. Urun: Uzun Şeker - 0.75 TL
# </p>

# %%
# 5.Problemin Çözümünü Buraya Yazınız

x = int(input("Kaydi yapilcak ürün sayisini giriniz:"))

ürünler = {}
for i in range(x):
    ürününAdi = input(f"{i+1}. ürünün ismini giriniz:")
    ürününFiyati = float(input(f"{i+1}. ürünün fiyatini giriniz:"))
    ürünler[ürününAdi] = ürününFiyati

print("Kaydedilen ürünler:")
for ürününAdi, ürününFiyati in ürünler.items():
    print(f"{ürününAdi}: {ürününFiyati:.2f} TL")
# Out:
# Kaydedilen ürünler:
# Mentos: 1.00 TL
# Meybuz: 0.25 TL
# Uzun Şeker: 0.75 TL

# %% [markdown]
# # Problem 6 Türkçe Karakter Çevirici
# Programa girilen dosya ismindeki Türkçe karakterleri, İngilizce'ye çeviren programı yazınız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen dosya ismi giriniz: fotoğraf.jpeg
# <br>
# Dosya ismi: fotograf.jpeg
# <br>
# <br>
# Lutfen dosya ismi giriniz: ışık.png
# <br>
# Dosya ismi: isik.png
# </p>

# %%
# 6.Problemin Çözümünü Buraya Yazınız

dosyaİsmi = input("Dosya ismini giriniz:")
yeniDosyaİsmi = ""

for harf in dosyaİsmi:
    if harf == "ç":
        yeniDosyaİsmi += "c"
    elif harf == "ğ":
        yeniDosyaİsmi += "g"
    elif harf == "ı":
        yeniDosyaİsmi += "i"
    elif harf == "ö":
        yeniDosyaİsmi += "o"
    elif harf == "ş":
        yeniDosyaİsmi += "s"
    elif harf == "ü":
        yeniDosyaİsmi += "u"
    else:
        yeniDosyaİsmi += harf

print(f"Dosya adi:{dosyaİsmi}")
print(f"Yeni dosya adi:{yeniDosyaİsmi}")
# Out:
# Dosya adi:ışık.png
# Yeni dosya adi:isik.png

# %% [markdown]
# # Problem 7 Sayı Tahmin Oyunu ama Bilgisayar Tahmin Ediyor :)
# Sayı tahmin oyunu: İki oyuncudan birinin, 0 ile 100 arasında bir sayı tutması ile başlar. Diğer oyuncu ise tahminler yaparak tutulan sayıyı bulmaya çalışır ve yaptığı her tahminde sayıyı tutmuş olan oyuncudan YUKARI veya AŞAĞI olarak geri bildirim alır. Sayıyı bildiğinde ise rakip oyuncu kaç tahminde (kaç denemede) bildiğini söyler.
#
# Senden yazmanı beklediğimiz program ise Python'ın tahminleri yapan tarafta olacağı bir oyun oluşturman. Yani sen 0 ile 100 arasında bir sayı tutacaksın ardından program senin tuttuğunuz sayıyı bulmaya çalışacak.
# <h4>Sample Input:</h4>
# Bu örnekte aklınızdan 90 tuttuğunuzu varsayalım.
# <p>
# Oyun başlıyor lutfen aklindan bir sayi tut! Tuttun mu, hazır mısın? : 1
# <br>
# Tahmin: 50
# <br>
# Durum: Yukari
# <br>
# Tahmin: 75
# <br>
# Durum: Yukari
# <br>
# Tahmin: 87
# <br>
# Durum: Yukari
# <br>
# Tahmin: 93
# <br>
# Durum: Asagi
# <br>
# Tahmin: 90
# <br>
# Durum: Bildin
# </p>

# %%
# 7.Problemin Çözümünü Buraya Yazınız

import random

def tahmin_et():
    minSayi = 0
    maxSayi = 101
    tahmin = -1
    denemeSayisi = 0

    print("0 ile 100 arasinda bir sayi tuttuysan eğer bakalim kaç denemede bulabileceğim!")

    while tahmin != "doğru":
        tahmin = random.randint(minSayi, maxSayi)
        print("Tahminim:", tahmin)
        denemeSayisi += 1

        cevap = input("Doğru mu, yukari mi, aşaği mi? ").lower()
        if cevap == "doğru":
            print(f"Buldum! {denemeSayisi} denemede doğru tahmin ettim.")
            tahmin = "doğru"
        elif cevap == "asaği":
            maxSayi = tahmin - 1
        elif cevap == "yukari":
            minSayi = tahmin + 1
        else:
            print("Lütfen 'doğru', 'yukari' veya 'aşaği' yanit verin.")

tahmin_et()
# Out:
# 0 ile 100 arasinda bir sayi tuttuysan eğer bakalim kaç denemede bulabileceğim!
# Tahminim: 84
# Tahminim: 6
# Tahminim: 9
# Tahminim: 41
# Tahminim: 48
# Tahminim: 44
# Tahminim: 43
# Tahminim: 42
# Buldum! 8 denemede doğru tahmin ettim.

# %% [markdown]
# # Problem 8 Net Yaş Hesaplayıcı
#
# Kullanıcının bugünün güncel tarihine kadar yaşadığı ay, gün, yıl süresini hesaplayan bir Python kodu yazınız. (Her ay 30 gün kabul edilmeyecektir. Kodu yazarken hangi ayın kaç gün olduğuna [Şubat ayının 29 gün olduğu yıllar dahil] dikkat edin.)

# %%
# 8.Problemin Çözümünü Buraya Yazınız

from datetime import date

dogumTarihi = input("Doğum tarihinizi (GG/AA/YYYY şeklinde) giriniz:")
dogumTarihi = date(int(dogumTarihi[6:]), int(dogumTarihi[3:5]), int(dogumTarihi[:2]))

bugun = date.today()

fark = bugun - dogumTarihi

yil = int(fark.days / 365)
ay = int((fark.days % 365) / 30)
gun = (fark.days % 365) % 30

print(f"Yaşadiğiniz yil, ay ve gün sayisi: {yil} yil, {ay} ay, {gun} gün")
# Out:
# Yaşadiğiniz yil, ay ve gün sayisi: 25 yil, 5 ay, 24 gün

# %% [markdown]
# # Problem 9 Tek-Çift
#
# Kullanıcıdan 'q' tuşuna basana kadar rastgele sayılar alın. Tek olanları bir listeye, çift olanları bir başka listeye büyükten küçüğe sıralanacak şekilde atın. Listeleri ekrana yazdıran bir kod yazın.

# %%
# 9.Problemin Çözümünü Buraya Yazınız

import random

çiftSayilar = []
tekSayilar = []

while True:
    sayi = input("Bir sayi girin (Çikmak için 'q' ya basin): ")
    if sayi == "q":
        break
    sayi = int(sayi)
    if sayi % 2 == 0:
        çiftSayilar.append(sayi)
    else:
        tekSayilar.append(sayi)

çiftSayilar.sort(reverse=True)
tekSayilar.sort(reverse=True)

print(f"Çift sayilar:{çiftSayilar}")
print(f"Tek sayilar:{tekSayilar}")
# Out:
# Çift sayilar:[86, 24, 6, 4, 2]
# Tek sayilar:[65, 45, 15, 9, 7]

# %% [markdown]
#  # Problem 10 Altıgen Çizimi
#
# Kullanıcıdan altıgenin kaç satırdan oluşacağı ve orta satırında kaç karakter olacağı bilgisini alarak '*' karakteri ile bir altıgen çizin. (For loop kullanabilirsiniz.)

# %%
# 10.Problemin Çözümünü Buraya Yazınız

# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
# 1.Problemin Çözümünü Buraya Yazınız
phoneNumbers = {"Ahmet":"05326781319","Burak":"05414741258","Cansu":"05363719539","Didem":"05453126269","Elif":"05619984521","Ferit":"05495412354"}
print("Rehberdeki isimler:", phoneNumbers.keys())

name = input("Lütfen numarasini öğrenmek istediğiniz kişinin adini giriniz:")
print(f"{name} isimli kişinin numarasi şu şekildedir:", phoneNumbers[name])
# Out:
# Rehberdeki isimler: dict_keys(['Ahmet', 'Burak', 'Cansu', 'Didem', 'Elif', 'Ferit'])
# Elif isimli kişinin numarasi şu şekildedir: 05619984521

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
# 2.Problemin Çözümünü Buraya Yazınız
companyEmp = {"Furkan Korkmaz":{"Memleket":"Ağri","Yaş":33,"Görev":"Müdür"},"Görkem Adigüzel":{"Memleket":"Malatya","Yaş":24,"Görev":"Kalite Kontrol Uzmani"},"Berkant Keskin":{"Memleket":"Denizli","Yaş":29,"Görev":"Yönetici"},"Ferit Korhan":{"Memleket":"Eskişehir","Yaş":25,"Görev":"Makine Mühendisi"}}
print("Şirket çalişanlarinin isimleri:", companyEmp.keys())

name = input("Lütfen bilgilerini görüntülemek istediğiniz çalişanin ismini giriniz:")
print(f"{name} isimli çalişanin bilgileri şu şekildedir: Memleket:",companyEmp[name]["Memleket"],"Yaş:",companyEmp[name]["Yaş"],"Görev:",companyEmp[name]["Görev"])
# Out:
# Şirket çalişanlarinin isimleri: dict_keys(['Furkan Korkmaz', 'Görkem Adigüzel', 'Berkant Keskin', 'Ferit Korhan'])
# Ferit Korhan isimli çalişanin bilgileri şu şekildedir: Memleket: Eskişehir Yaş: 25 Görev: Makine Mühendisi

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
# 3.Problemin Çözümünü Buraya Yazınız

studentGrade = {"Eda Gül":[65,79,88],"Deniz Kol":[95,100,100],"Ayşe Dal":[78,65,92]}
print("Öğrencilerin isimleri:", studentGrade.keys())

name = input("Lütfen notlarini görmek istediğiniz öğrencinin adini giriniz:")
print(f"{name} isimli notlari şu şekildedir:", studentGrade[name])
# Out:
# Öğrencilerin isimleri: dict_keys(['Eda Gül', 'Deniz Kol', 'Ayşe Dal'])
# Eda Gül isimli notlari şu şekildedir: [65, 79, 88]

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
cars = ["Bmw","Mercedes","Opel","Mazda"]
print(cars)
# 2-  Liste Kaç elemanlıdır ?
print(len(cars))
# 3-  Listenin ilk ve son elemanı nedir ?
print("Listenin ilk elemani:",cars[0])
print("Listenin son elemani:",cars[-1])
# 4-  Mazda değerini Toyota ile değiştirin.
cars[-1]="Toyota"
print(cars)
# 5-  Listenin -2 indeksindeki değer nedir ?
print("-2 indexdeki değer:",cars[-2])
# 6-  Listenin ilk 3 elemanını alın.
print(cars[0:3])
# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
print(cars)
cars[-2:] = ["Toyota","Renault"]
print(cars)
# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
print(cars + ["Audi","Nissan"])
# 9- Listenin son elemanını silin.
cars.pop(-1)
print(cars)
# 10- Liste elemanlarını tersten yazdırınız.
cars.reverse()
print(cars)
# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 

studentA = ["Yiğit","Bilgi",2010,[70,60,70]]
studentB = ["Sena","Turan",1999,[80,80,70]]
studentC = ["Ahmet","Turan",1998,[80,70,90]]

# 12- Liste elemanlarını ekrana yazdırınız.

print(f"{studentA[0]} {studentA[1]}, {2023-studentA[2]} yaşinda ve not ortalamasi {(studentA[3][0]+studentA[3][1]+studentA[3][2])/3}.")
print(f"{studentB[0]} {studentB[1]}, {2023-studentB[2]} yaşinda ve not ortalamasi {(studentB[3][0]+studentB[3][1]+studentB[3][2])/3}.")
print(f"{studentC[0]} {studentC[1]}, {2023-studentC[2]} yaşinda ve not ortalamasi {(studentC[3][0]+studentC[3][1]+studentC[3][2])/3}.")

  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print(names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0,"Sena")
print(names)

# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")
print(names)

# 16-  "Ali" listenin bir elemanı mıdır ?
print("Ali" in names)
    
# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print(names)
# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print(names)

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
print(years)
# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
list =str.split(",")
print(list)
# 21- years dizisinde kaç tane 1998 değeri vardır ?
print(years.count(1998))

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
print(years)

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
brands = []

brand1 = input("Marka giriniz:")
print(f"1.Marka:{brand1}")
brands.append(brand1)

brand2 = input("Marka giriniz:")
print(f"2.Marka:{brand2}")
brands.append(brand2)

brand3 = input("Marka giriniz:")
print(f"3.Marka:{brand3}")
brands.append(brand3)

print(brands)
# Out:
# ['Bmw', 'Mercedes', 'Opel', 'Mazda']
# 4
# Listenin ilk elemani: Bmw
# Listenin son elemani: Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# -2 indexdeki değer: Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# ['Bmw', 'Mercedes', 'Toyota']
# ['Toyota', 'Mercedes', 'Bmw']
# Yiğit Bilgi, 13 yaşinda ve not ortalamasi 66.66666666666667.
# Sena Turan, 24 yaşinda ve not ortalamasi 76.66666666666667.
# Ahmet Turan, 25 yaşinda ve not ortalamasi 80.0.
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# True
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# [1987, 1998, 1998, 2000]
# ['Chevrolet', 'Dacia']
# 2
# []
# 1.Marka:Apple
# 2.Marka:Monster
# 3.Marka:Mercedes
# ['Apple', 'Monster', 'Mercedes']
